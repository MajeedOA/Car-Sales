# %% [markdown]
# **CANADA CAR SALES**
#
# The dataset provides an overview of car sales trends in Canada from 2019 to 2021. It examines how different vehicle types performed in the market, highlighting key sales trends, best-selling models, and the impact of external factors on the automotive industry. The data is useful for understanding consumer preferences and market shifts over time.
# This dataset contains records of car sales across Canada, including details on vehicle categories, specific models, and their sales volumes. The analysis explores overall sales trends, identifying which car types gained or lost popularity during the period. Data visualizations help illustrate the shifts in consumer demand and potential factors influencing these changes, such as economic conditions or supply chain disruptions.
#
# 1. Introduction
# 2. Data Import and Preparation
# 3. Exploratory Data Analysis
# 4. Key Questions
# 5. Conclusion
#
# **Key features**
# 1. Time-based sales data covering 2019 to 2021
# 2. Breakdown of vehicle sales by category
# 3. Individual car model sales figures
# 4. Data visualization of sales trends
# 5. Top 10 Best selling models.
#
# **Key Question**
# 1. Find the highest and lowest selling car models?
# 2. Calculate H1 vs H2 sales comparison?
# 3. Find the most common peak sales month?
# 4. How did overall car sales in Canada change from 2019 to 2021?
# 5. Which vehicle categories had the highest sales?
# 6. What were the top 10-selling car models during this period?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
 import pandas as pd


df= pd.read_csv(r"C:\Users\MY LAPTOP\Downloads\Canadasalesdata.csv")
df
# Out:
#                   Model  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0             Acura MDX   93  389   782   611   550   501     0     0     0
# 1               Audi Q7  210  210   236   303   292   303     0     0     0
# 2               Audi Q8  130  130   146   211   203   211     0     0     0
# 3                BMW X5  323  323   364   518   498   518     0     0     0
# 4                BMW X6   72   72    81   113   108   113     0     0     0
# ..                  ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 231      Subaru Outback  499  621   948  1065  1079   981  1074   845   644
# 232      Toyota 4Runner  605  393   784   762   854   681   824   903   522
# 233   Toyota Highlander  729  792  1184  1095  1185  1423  1347  1336  1114
# 234    Volkswagen Atlas  530  521   822   925   881   725   761   769   748
# 235  Volkswagen Touareg    7    2     5     2     1     3     2     0     1
#
#       Oct   Nov   Dec  Sumofsales Category  Year
# ...

# %%
pd.set_option("display.max_rows", 237)

# %%
df["average_monthly_sales"] =(df["Sumofsales"]/12).astype(int)
df["Q1 Sales"] = df[["Jan", "Feb", "Mar"]].sum(axis=1)
df["Q2 Sales"] = df[["Apr", "May", "Jun"]].sum(axis=1)
df["Q3 Sales"] = df[["Jul", "Aug", "Sep"]].sum(axis=1)
df["Q4 Sales"] = df[["Oct", "Nov", "Dec"]].sum(axis=1)
df["H1_Sales"] = df.iloc[:, 1:7].sum(axis=1)  # Jan to Jun sales
df["H2_Sales"] = df.iloc[:, 7:13].sum(axis=1) # Jul to Dec sales
df["Peak_Month"] = df.iloc[:, 1:13].idxmax(axis=1) # Month with highest sales
df
# Out:
#                   Model  Jan  Feb   Mar   Apr   May   Jun   Jul   Aug   Sep  \
# 0             Acura MDX   93  389   782   611   550   501     0     0     0
# 1               Audi Q7  210  210   236   303   292   303     0     0     0
# 2               Audi Q8  130  130   146   211   203   211     0     0     0
# 3                BMW X5  323  323   364   518   498   518     0     0     0
# 4                BMW X6   72   72    81   113   108   113     0     0     0
# ..                  ...  ...  ...   ...   ...   ...   ...   ...   ...   ...
# 231      Subaru Outback  499  621   948  1065  1079   981  1074   845   644
# 232      Toyota 4Runner  605  393   784   762   854   681   824   903   522
# 233   Toyota Highlander  729  792  1184  1095  1185  1423  1347  1336  1114
# 234    Volkswagen Atlas  530  521   822   925   881   725   761   769   748
# 235  Volkswagen Touareg    7    2     5     2     1     3     2     0     1
#
# ...

# %%
Model = df.groupby('Model')['Sumofsales'].sum()
Model
# Out:
# Model
# Acura MDX                         6847
# Alfa Romeo Stelvio                1710
# Audi Q3                          17641
# Audi Q5                          35460
# Audi Q7                           3802
# Audi Q8                           2354
# Audi eTron                        1672
# BMW X1                           12840
# BMW X2                            4051
# BMW X5                            7329
# BMW X6                            1587
# BMW X7                            3487
# Buick Enclave                     4707
# Cadillac Escalade                 5964
# Cadillac XT4                     12337
# Cadillac XT5                      7101
# Cadillac XT6                      2465
# Chevrolet Blazer                 19071
# Chevrolet Suburban                4372
# Chevrolet Tahoe                   8504
# Chevrolet TrailBlazer             2487
# Chevrolet Traverse               11097
# Dodge Durango                    15287
# Ford Bronco Sport                  195
# ...

# %%
total_sales = df['Sumofsales'].sum()
total_sales
# Out:
# 868665

# %%
df['Sumofsales'].mean()
# Out:
# 3680.7838983050847

# %%
Sales_range = df['Sumofsales'].max() - df['Sumofsales'].min()
Sales_range
# Out:
# 23183

# %%
#Total sales for each year
total_sales_2019 = df[df["Year"] == 2019]["Sumofsales"].sum()
total_sales_2020 = df[df["Year"] == 2020]["Sumofsales"].sum()
total_sales_2021 = df[df["Year"] == 2021]["Sumofsales"].sum()

print("Total Sales in 2019:", total_sales_2019)
print("Total Sales in 2020:", total_sales_2020)
print("Total Sales in 2021:", total_sales_2021)
# Out:
# Total Sales in 2019: 390825
# Total Sales in 2020: 341736
# Total Sales in 2021: 136104

# %% [markdown]
#  1. Find the highest and lowest selling car models

# %%
highest_selling_model = df.loc[df["Sumofsales"].idxmax(), ["Model", "Sumofsales"]]
lowest_selling_model = df.loc[df["Sumofsales"].idxmin(), ["Model", "Sumofsales"]]

lowest_selling_model,highest_selling_model

# Plot a bar chart
plt.figure(figsize=(16, 10))
plt.bar(df["Model"],df["Sumofsales"], color=["green", "red"])
plt.xlabel("Car Model")
plt.ylabel("Total Sales")
plt.title("Highest and Lowest Selling Car Models")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Calculate H1 vs H2 sales comparison

# %%
h1_h2_sales_comparison = df[["H1_Sales", "H2_Sales"]].sum()
h1_h2_sales_comparison

# Plot a bar chart
plt.figure(figsize=(8, 6))
h1_h2_sales_comparison.plot(kind='bar', color=['blue', 'orange'])
plt.xlabel("Sales Period")
plt.ylabel("Total Sales")
plt.title("H1 vs H2 Sales Comparison")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Find the most common peak sales month

# %%
most_common_peak_month = df["Peak_Month"].mode()[0]

most_common_peak_month

# Count the occurrences of each peak month
peak_month_counts = df["Peak_Month"].value_counts()

# Plot a bar chart
plt.figure(figsize=(10, 6))
peak_month_counts.plot(kind='bar', color='skyblue')
plt.xlabel("Peak Month")
plt.ylabel("Count")
plt.title("Most Common Peak Sales Month")
plt.xticks(rotation=0)
plt.axvline(x=most_common_peak_month, color='red', linestyle='--', label='Most Common Peak Month')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. How did overall car sales in Canada change from 2019 to 2021?

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x=sales_per_year.index, y=sales_per_year.values, marker="o", linestyle="-", color="b")
plt.title("Total Car Sales Trends Over the Years")
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.grid(True)

# %% [markdown]
# 5. Which vehicle categories had the highest sales

# %%
sales_per_category = df.groupby("Category")["Sumofsales"].sum()
sales_per_category

plt.figure(figsize=(8,5))
sns.barplot(x="Category", hue='Category', y="Sumofsales", data=df, estimator=sum, errorbar=None, palette="muted")
plt.title("Sum of Sales by Category")
plt.ylabel("Sum of Sales")
plt.xlabel("Category")
plt.show()

# %% [markdown]
# 6. What were the top 10-selling car models during this period?

# %%
top_models = df.nlargest(10, "Sumofsales")
top_models

plt.figure(figsize=(12, 6))
sns.barplot(x=top_models["Sumofsales"], y=top_models["Model"], hue=top_models["Model"], palette="viridis")
plt.title("Top 10 Best-Selling Car Models in Canada")
plt.xlabel("Total Sales")
plt.ylabel("Car Model")
plt.show()

# %% [markdown]
# Conclusion
#
# After analyzing the car sales data in Canada, there was a noticeable drop in total sales from 2019 to 2021, which could be due to external factors like economic shifts or supply chain disruptions. Mid-size SUVs (MS category) had the highest sales, showing that consumers prefer larger vehicles, possibly for their practicality and comfort. Among individual models, the Jeep Wrangler was one of the best-selling vehicles, reinforcing the popularity of SUVs in the market.
#
# This analysis provides useful insights,graphs were plotted to visualize the sales trends to show differences in the column. It would be interesting to compare these trends with electric vehicle (EV) sales or look at how pricing impacts consumer choices. Additionally, examining regional trends across Canada could give a better picture of where demand is strongest.
#
# Overall, this dataset gave a solid overview of sales trends, and with more data, we could dive even deeper into what drives the Canadian automotive market.
